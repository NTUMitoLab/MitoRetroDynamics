# %% [markdown]
# # Frequency Response Simulation and Analysis

# %%
using Pkg
Pkg.activate(dirname(@__DIR__))
# Out:
#   Activating environment at `~/MitoChannelAnalysis/FrequencyResponse/Project.toml`

# %%
Pkg.status()
# Out:
#      Project FrequencyResponse v0.1.0
#       Status `~/MitoChannelAnalysis/FrequencyResponse/Project.toml`
#   [479239e8] Catalyst v6.3.1
#   [717857b8] DSP v0.6.10
#   [31a5f54b] Debugger v0.6.7
#   [0c46a032] DifferentialEquations v6.16.0
#   [5ce5e58b] FindSteadyStates v0.1.1
#   [41a02a25] Folds v0.2.1
#   [f6369f11] ForwardDiff v0.10.16
#   [7f56f5a3] LSODA v0.6.2
#   [b964fa9f] LaTeXStrings v1.2.0
#   [961ee093] ModelingToolkit v4.5.0
#   [0db19996] NBInclude v2.2.0
#   [c030b06c] ODE v2.12.0
#   [429524aa] Optim v1.2.4
#   [d96e819e] Parameters v0.12.2
#   [91a5bcdd] Plots v1.10.5
#   [49802e3a] ProgressBars v1.0.0
#   [d330b81b] PyPlot v2.9.0
#   [189a3867] Reexport v1.0.0
#   [413adb04] RetroSignalModel v0.2.0 `https://github.com/stevengogogo/RetroSignalModel.jl#master`
#   [295af30f] Revise v3.1.12
#   [ebc72ef8] SciPy v0.1.0
#   [2913bbd2] StatsBase v0.33.3
#   [c3572dad] Sundials v4.4.1
#   [10745b16] Statistics
#   [8dfed614] Test

# %%
using FrequencyResponse
using RetroSignalModel
using DifferentialEquations
using LaTeXStrings
using ProgressBars
using DSP
import PyPlot
import Folds
const plt = PyPlot;

# %%
function show_all(sol)
        prl = Dict(
        :name=> [:bmhmks, :Rtg1_n, :Rtg3_n, :Rtg13_n],
        :label=> [string("Output\n",i)   for i in ["Bmh/Mksp (nM)", "Nucleus Rtg1p (nM)", "Nucleus Rtg3p (nM)", "Nucleus Rtg1/3p (nM)"]  ]
    )
    
    figs, axes = [], []
    
    for (n,l) in zip(prl[:name], prl[:label])
        fig_,ax_ = plotSol(sol, n, dynmodel; ylabel_output= l)
        push!(figs, fig_)
        push!(axes, ax_)
    end
    return Fig.(figs, axes,  prl[:name])
end;

function output(us, inds)
    return [ sum(u[inds]) for u in us]
end
# Out:
# output (generic function with 1 method)

# %%
pr_is = RetroSignalModel.rtgM4().protein_lookup
rtg13_n = pr_is[:Rtg13_n]
rtg3_n = pr_is[:Rtg3_n]
# Out:
# 4-element Vector{Int64}:
#  12
#  13
#  16
#  17

# %% [markdown]
# ## Setup

# %%
i_sol_PLACE_HOLDER=6
# Load Model
RTGm = RetroSignalModel.rtgM4(i_sol_PLACE_HOLDER)
param= (; u=RTGm.u, p=RTGm.p);

# %%
# Dynamical Signal
dynmodel = DynModel(
    model = RTGm.model,
    u = param.u,
    p = param.p,
    solver= Rosenbrock23(),
    signal_func = PosSine(ω=0.05,θ=(3/2)*π, amp=1),
    input_i = 1,
    tspan=(0.,500.),
    init_ss = true # Get steady state
);

# %% [markdown]
# ## Sinusoidal Response

# %%
# Solve 
@time sol = solve(dynmodel;dtmax=1., reltol=1e-15,abstol=1e-8);
figsD_sin = show_all(sol)
# Out:
# PyPlot.Figure(PyObject <Figure size 300x300 with 2 Axes>)
# PyPlot.Figure(PyObject <Figure size 300x300 with 2 Axes>)
# PyPlot.Figure(PyObject <Figure size 300x300 with 2 Axes>)
# PyPlot.Figure(PyObject <Figure size 300x300 with 2 Axes>)
#  21.768487 seconds (130.82 M allocations: 5.919 GiB, 9.59% gc time, 10.78% compilation time)
# 4-element Vector{Fig}:
#  Fig(PyPlot.Figure(PyObject <Figure size 300x300 with 2 Axes>), nothing, :bmhmks)
#  Fig(PyPlot.Figure(PyObject <Figure size 300x300 with 2 Axes>), nothing, :Rtg1_n)
#  Fig(PyPlot.Figure(PyObject <Figure size 300x300 with 2 Axes>), nothing, :Rtg3_n)
#  Fig(PyPlot.Figure(PyObject <Figure size 300x300 with 2 Axes>), nothing, :Rtg13_n)

# %%
#[save.(figsD_sin, "Sine_5e-2rad", "FrequencyResponse/result/sine"; 
       # format= f) for f in ["pdf", "svg"]];

# %% [markdown]
# ## Hysteresis

# %%
dynmodel_sq = DynModel(dynmodel; 
                       init_ss=false, 
                       signal_func= SquarePulse(
                                    t_str = 125.,
                                    t_end = 375,
                                    amp_l =0.,
                                    amp_h = 1.) 
                        );
sol = solve(dynmodel_sq;tmax=1.);

figsD_SqPulse = show_all(sol)
# Out:
# PyPlot.Figure(PyObject <Figure size 300x300 with 2 Axes>)
# PyPlot.Figure(PyObject <Figure size 300x300 with 2 Axes>)
# PyPlot.Figure(PyObject <Figure size 300x300 with 2 Axes>)
# PyPlot.Figure(PyObject <Figure size 300x300 with 2 Axes>)
# 4-element Vector{Fig}:
#  Fig(PyPlot.Figure(PyObject <Figure size 300x300 with 2 Axes>), nothing, :bmhmks)
#  Fig(PyPlot.Figure(PyObject <Figure size 300x300 with 2 Axes>), nothing, :Rtg1_n)
#  Fig(PyPlot.Figure(PyObject <Figure size 300x300 with 2 Axes>), nothing, :Rtg3_n)
#  Fig(PyPlot.Figure(PyObject <Figure size 300x300 with 2 Axes>), nothing, :Rtg13_n)

# %%
[save.(figsD_SqPulse, "Pulse_150sec", "FrequencyResponse/result/pulse"; 
        format= f) for f in ["pdf", "svg"]];
# Out:
# IOError: mkdir("FrequencyResponse/result/pulse"; mode=0o777): no such file or directory (ENOENT)
#
# Stacktrace:
#   [1] uv_error
#     @ ./libuv.jl:97 [inlined]
#   [2] mkdir(path::String; mode::UInt16)
#     @ Base.Filesystem ./file.jl:179
#   [3] mkdir
#     @ ./file.jl:172 [inlined]
#   [4] save(f::Fig, secName::String, path_dir::String; format::String, transparent::Bool, bbox_inches::String, kwags::Base.Iterators.Pairs{Union{}, Union{}, Tuple{}, NamedTuple{(), Tuple{}}})
#     @ FrequencyResponse ~/MitoChannelAnalysis/FrequencyResponse/src/plot.jl:19
#   [5] #31
#     @ ./broadcast.jl:1297 [inlined]
#   [6] _broadcast_getindex_evalf
#     @ ./broadcast.jl:648 [inlined]
#   [7] _broadcast_getindex
#     @ ./broadcast.jl:621 [inlined]
#   [8] getindex
#     @ ./broadcast.jl:575 [inlined]
#   [9] copy
#     @ ./broadcast.jl:922 [inlined]
#  [10] materialize(bc::Base.Broadcast.Broadcasted{Base.Broadcast.DefaultArrayStyle{1}, Nothing, Base.Broadcast.var"#31#32"{Base.Iterators.Pairs{Symbol, String, Tuple{Symbol}, NamedTuple{(:format,), Tuple{String}}}, typeof(save)}, Tuple{Vector{Fig}, Base.RefValue{String}, Base.RefValue{String}}})
#     @ Base.Broadcast ./broadcast.jl:883
#  [11] (::var"#5#6")(f::String)
#     @ Main ./none:0
#  [12] iterate
#     @ ./generator.jl:47 [inlined]
#  [13] collect(itr::Base.Generator{Vector{String}, var"#5#6"})
#     @ Base ./array.jl:678
#  [14] top-level scope
#     @ In[11]:1
#  [15] eval
#     @ ./boot.jl:360 [inlined]
#  [16] include_string(mapexpr::typeof(REPL.softscope), mod::Module, code::String, filename::String)
#     @ Base ./loading.jl:1116

# %% [markdown]
# ## Multiple Step Response
#
# - Follower
# - No overshoot

# %%
dynmodel_sq = DynModel(dynmodel; 
                       init_ss=false, 
                       signal_func= SquarePulse(
                                    t_str = 0.,
                                    t_end = 160,
                                    amp_l =0.,
                                    amp_h = 0.)  +
                                    SquarePulse(
                                    t_str = 160.1,
                                    t_end = 320,
                                    amp_l =0,
                                    amp_h = 0.5)  +
                                    SquarePulse(
                                    t_str = 320.1,
                                    t_end = 500,
                                    amp_l =0,
                                    amp_h = 1.) 
                        );
solPulses = solve(dynmodel_sq;tmax=1.);

figsD_SqPulses = show_all(solPulses)
# Out:
# PyPlot.Figure(PyObject <Figure size 300x300 with 2 Axes>)
# PyPlot.Figure(PyObject <Figure size 300x300 with 2 Axes>)
# PyPlot.Figure(PyObject <Figure size 300x300 with 2 Axes>)
# PyPlot.Figure(PyObject <Figure size 300x300 with 2 Axes>)
# 4-element Vector{Fig}:
#  Fig(PyPlot.Figure(PyObject <Figure size 300x300 with 2 Axes>), nothing, :bmhmks)
#  Fig(PyPlot.Figure(PyObject <Figure size 300x300 with 2 Axes>), nothing, :Rtg1_n)
#  Fig(PyPlot.Figure(PyObject <Figure size 300x300 with 2 Axes>), nothing, :Rtg3_n)
#  Fig(PyPlot.Figure(PyObject <Figure size 300x300 with 2 Axes>), nothing, :Rtg13_n)

# %%
[save.(figsD_SqPulses, "Pulse_160sec320sec", "FrequencyResponse/result/pulse"; 
        format= f) for f in ["pdf", "svg"]];
# Out:
# IOError: mkdir("FrequencyResponse/result/pulse"; mode=0o777): no such file or directory (ENOENT)
#
# Stacktrace:
#   [1] uv_error
#     @ ./libuv.jl:97 [inlined]
#   [2] mkdir(path::String; mode::UInt16)
#     @ Base.Filesystem ./file.jl:179
#   [3] mkdir
#     @ ./file.jl:172 [inlined]
#   [4] save(f::Fig, secName::String, path_dir::String; format::String, transparent::Bool, bbox_inches::String, kwags::Base.Iterators.Pairs{Union{}, Union{}, Tuple{}, NamedTuple{(), Tuple{}}})
#     @ FrequencyResponse ~/MitoChannelAnalysis/FrequencyResponse/src/plot.jl:19
#   [5] #31
#     @ ./broadcast.jl:1297 [inlined]
#   [6] _broadcast_getindex_evalf
#     @ ./broadcast.jl:648 [inlined]
#   [7] _broadcast_getindex
#     @ ./broadcast.jl:621 [inlined]
#   [8] getindex
#     @ ./broadcast.jl:575 [inlined]
#   [9] copy
#     @ ./broadcast.jl:922 [inlined]
#  [10] materialize(bc::Base.Broadcast.Broadcasted{Base.Broadcast.DefaultArrayStyle{1}, Nothing, Base.Broadcast.var"#31#32"{Base.Iterators.Pairs{Symbol, String, Tuple{Symbol}, NamedTuple{(:format,), Tuple{String}}}, typeof(save)}, Tuple{Vector{Fig}, Base.RefValue{String}, Base.RefValue{String}}})
#     @ Base.Broadcast ./broadcast.jl:883
#  [11] (::var"#7#8")(f::String)
#     @ Main ./none:0
#  [12] iterate
#     @ ./generator.jl:47 [inlined]
#  [13] collect(itr::Base.Generator{Vector{String}, var"#7#8"})
#     @ Base ./array.jl:678
#  [14] top-level scope
#     @ In[13]:1
#  [15] eval
#     @ ./boot.jl:360 [inlined]
#  [16] include_string(mapexpr::typeof(REPL.softscope), mod::Module, code::String, filename::String)
#     @ Base ./loading.jl:1116

# %% [markdown]
# ## Merging Pulse and Sinusoidal Response

# %%
pulse = SquarePulse(t_str = 100.,t_end = 150.,amp_l =0., amp_h = 1.) 
sigFunc = pulse + SquarePulse(pulse; t_str=350, t_end=800.) * PosSine(ω=0.08, θ=π)

dynmodel_sq = DynModel(dynmodel; 
                       init_ss=false, 
                       signal_func= sigFunc,
                        tspan=(0.,800.)
                        );
sol = solve(dynmodel_sq;tmax=0.5);

figsD_SquareSine = show_all(sol)
# Out:
# PyPlot.Figure(PyObject <Figure size 300x300 with 2 Axes>)
# PyPlot.Figure(PyObject <Figure size 300x300 with 2 Axes>)
# PyPlot.Figure(PyObject <Figure size 300x300 with 2 Axes>)
# PyPlot.Figure(PyObject <Figure size 300x300 with 2 Axes>)
# 4-element Vector{Fig}:
#  Fig(PyPlot.Figure(PyObject <Figure size 300x300 with 2 Axes>), nothing, :bmhmks)
#  Fig(PyPlot.Figure(PyObject <Figure size 300x300 with 2 Axes>), nothing, :Rtg1_n)
#  Fig(PyPlot.Figure(PyObject <Figure size 300x300 with 2 Axes>), nothing, :Rtg3_n)
#  Fig(PyPlot.Figure(PyObject <Figure size 300x300 with 2 Axes>), nothing, :Rtg13_n)

# %%
[save.(figsD_SquareSine, "SquareSine_150sec", "FrequencyResponse/result/squareSine"; format= f) for f in ["pdf", "svg"]];
# Out:
# IOError: mkdir("FrequencyResponse/result/squareSine"; mode=0o777): no such file or directory (ENOENT)
#
# Stacktrace:
#   [1] uv_error
#     @ ./libuv.jl:97 [inlined]
#   [2] mkdir(path::String; mode::UInt16)
#     @ Base.Filesystem ./file.jl:179
#   [3] mkdir
#     @ ./file.jl:172 [inlined]
#   [4] save(f::Fig, secName::String, path_dir::String; format::String, transparent::Bool, bbox_inches::String, kwags::Base.Iterators.Pairs{Union{}, Union{}, Tuple{}, NamedTuple{(), Tuple{}}})
#     @ FrequencyResponse ~/MitoChannelAnalysis/FrequencyResponse/src/plot.jl:19
#   [5] #31
#     @ ./broadcast.jl:1297 [inlined]
#   [6] _broadcast_getindex_evalf
#     @ ./broadcast.jl:648 [inlined]
#   [7] _broadcast_getindex
#     @ ./broadcast.jl:621 [inlined]
#   [8] getindex
#     @ ./broadcast.jl:575 [inlined]
#   [9] copy
#     @ ./broadcast.jl:922 [inlined]
#  [10] materialize(bc::Base.Broadcast.Broadcasted{Base.Broadcast.DefaultArrayStyle{1}, Nothing, Base.Broadcast.var"#31#32"{Base.Iterators.Pairs{Symbol, String, Tuple{Symbol}, NamedTuple{(:format,), Tuple{String}}}, typeof(save)}, Tuple{Vector{Fig}, Base.RefValue{String}, Base.RefValue{String}}})
#     @ Base.Broadcast ./broadcast.jl:883
#  [11] (::var"#9#10")(f::String)
#     @ Main ./none:0
#  [12] iterate
#     @ ./generator.jl:47 [inlined]
#  [13] collect(itr::Base.Generator{Vector{String}, var"#9#10"})
#     @ Base ./array.jl:678
#  [14] top-level scope
#     @ In[15]:1
#  [15] eval
#     @ ./boot.jl:360 [inlined]
#  [16] include_string(mapexpr::typeof(REPL.softscope), mod::Module, code::String, filename::String)
#     @ Base ./loading.jl:1116

# %% [markdown]
# ## Impuse
# #'
# ### Short Impulse
#
# - Short Impuse Injection (duration=1 sec)

# %%
dynmodel_sq = DynModel(dynmodel; 
                       init_ss=false, 
                       signal_func= SquarePulse(t_str = 100.,t_end = 101,amp_l =0., amp_h = 1.) ,
                        tspan=(0.,500.)
                        );
sol = solve(dynmodel_sq;tmax=0.5);

figsD_PulseShort = show_all(sol)
# Out:
# PyPlot.Figure(PyObject <Figure size 300x300 with 2 Axes>)
# PyPlot.Figure(PyObject <Figure size 300x300 with 2 Axes>)
# PyPlot.Figure(PyObject <Figure size 300x300 with 2 Axes>)
# PyPlot.Figure(PyObject <Figure size 300x300 with 2 Axes>)
# 4-element Vector{Fig}:
#  Fig(PyPlot.Figure(PyObject <Figure size 300x300 with 2 Axes>), nothing, :bmhmks)
#  Fig(PyPlot.Figure(PyObject <Figure size 300x300 with 2 Axes>), nothing, :Rtg1_n)
#  Fig(PyPlot.Figure(PyObject <Figure size 300x300 with 2 Axes>), nothing, :Rtg3_n)
#  Fig(PyPlot.Figure(PyObject <Figure size 300x300 with 2 Axes>), nothing, :Rtg13_n)

# %%
[save.(figsD_PulseShort, "Impulse_1ec", "FrequencyResponse/result/Impulse"; 
format= f) for f in ["pdf", "svg"]];
# Out:
# IOError: mkdir("FrequencyResponse/result/Impulse"; mode=0o777): no such file or directory (ENOENT)
#
# Stacktrace:
#   [1] uv_error
#     @ ./libuv.jl:97 [inlined]
#   [2] mkdir(path::String; mode::UInt16)
#     @ Base.Filesystem ./file.jl:179
#   [3] mkdir
#     @ ./file.jl:172 [inlined]
#   [4] save(f::Fig, secName::String, path_dir::String; format::String, transparent::Bool, bbox_inches::String, kwags::Base.Iterators.Pairs{Union{}, Union{}, Tuple{}, NamedTuple{(), Tuple{}}})
#     @ FrequencyResponse ~/MitoChannelAnalysis/FrequencyResponse/src/plot.jl:19
#   [5] #31
#     @ ./broadcast.jl:1297 [inlined]
#   [6] _broadcast_getindex_evalf
#     @ ./broadcast.jl:648 [inlined]
#   [7] _broadcast_getindex
#     @ ./broadcast.jl:621 [inlined]
#   [8] getindex
#     @ ./broadcast.jl:575 [inlined]
#   [9] copy
#     @ ./broadcast.jl:922 [inlined]
#  [10] materialize(bc::Base.Broadcast.Broadcasted{Base.Broadcast.DefaultArrayStyle{1}, Nothing, Base.Broadcast.var"#31#32"{Base.Iterators.Pairs{Symbol, String, Tuple{Symbol}, NamedTuple{(:format,), Tuple{String}}}, typeof(save)}, Tuple{Vector{Fig}, Base.RefValue{String}, Base.RefValue{String}}})
#     @ Base.Broadcast ./broadcast.jl:883
#  [11] (::var"#11#12")(f::String)
#     @ Main ./none:0
#  [12] iterate
#     @ ./generator.jl:47 [inlined]
#  [13] collect(itr::Base.Generator{Vector{String}, var"#11#12"})
#     @ Base ./array.jl:678
#  [14] top-level scope
#     @ In[17]:1
#  [15] eval
#     @ ./boot.jl:360 [inlined]
#  [16] include_string(mapexpr::typeof(REPL.softscope), mod::Module, code::String, filename::String)
#     @ Base ./loading.jl:1116

# %%
dynmodel_sq = DynModel(dynmodel; 
                       init_ss=false, 
                       signal_func= SquarePulse(t_str = 100.,t_end = 120,amp_l =0., amp_h = 1.) ,
                        tspan=(0.,500.)
                        );
sol = solve(dynmodel_sq;tmax=0.2);

figsD_PulseLong = show_all(sol);

[save.(figsD_PulseLong, "Impulse_20ec", "FrequencyResponse/result/Impulse"; 
format= f) for f in ["pdf", "svg"]];
# Out:
# IOError: mkdir("FrequencyResponse/result/Impulse"; mode=0o777): no such file or directory (ENOENT)
#
# Stacktrace:
#   [1] uv_error
#     @ ./libuv.jl:97 [inlined]
#   [2] mkdir(path::String; mode::UInt16)
#     @ Base.Filesystem ./file.jl:179
#   [3] mkdir
#     @ ./file.jl:172 [inlined]
#   [4] save(f::Fig, secName::String, path_dir::String; format::String, transparent::Bool, bbox_inches::String, kwags::Base.Iterators.Pairs{Union{}, Union{}, Tuple{}, NamedTuple{(), Tuple{}}})
#     @ FrequencyResponse ~/MitoChannelAnalysis/FrequencyResponse/src/plot.jl:19
#   [5] #31
#     @ ./broadcast.jl:1297 [inlined]
#   [6] _broadcast_getindex_evalf
#     @ ./broadcast.jl:648 [inlined]
#   [7] _broadcast_getindex
#     @ ./broadcast.jl:621 [inlined]
#   [8] getindex
#     @ ./broadcast.jl:575 [inlined]
#   [9] copy
#     @ ./broadcast.jl:922 [inlined]
#  [10] materialize(bc::Base.Broadcast.Broadcasted{Base.Broadcast.DefaultArrayStyle{1}, Nothing, Base.Broadcast.var"#31#32"{Base.Iterators.Pairs{Symbol, String, Tuple{Symbol}, NamedTuple{(:format,), Tuple{String}}}, typeof(save)}, Tuple{Vector{Fig}, Base.RefValue{String}, Base.RefValue{String}}})
#     @ Base.Broadcast ./broadcast.jl:883
#  [11] (::var"#13#14")(f::String)
#     @ Main ./none:0
#  [12] iterate
#     @ ./generator.jl:47 [inlined]
#  [13] collect(itr::Base.Generator{Vector{String}, var"#13#14"})
#     @ Base ./array.jl:678
#  [14] top-level scope
#     @ In[18]:10
#  [15] eval
#     @ ./boot.jl:360 [inlined]
#  [16] include_string(mapexpr::typeof(REPL.softscope), mod::Module, code::String, filename::String)
#     @ Base ./loading.jl:1116

# %%
fig_, ax_ = plt.subplots(figsize=(5,5))
pr = pr_is
ax_.plot(sol.t, [sum(u[pr[:Rtg13_n]]) for u in sol.u], linewidth=3, color="blue")
ax_.xaxis.set_ticks([0,500])
ax_.set_xlim([0,500])
ax_.set_ylim([70,110])
ax_.yaxis.set_ticks([70,110])
# Out:
# PyPlot.Figure(PyObject <Figure size 500x500 with 1 Axes>)
# 2-element Vector{PyCall.PyObject}:
#  PyObject <matplotlib.axis.YTick object at 0x7fcf095cde20>
#  PyObject <matplotlib.axis.YTick object at 0x7fcf095cd6a0>

# %%
fig_.savefig("FrequencyResponse/result/synthetic_wave/output_Rtg13_n.pdf", box_inches="tight")
# Out:
# sys:1: MatplotlibDeprecationWarning: savefig() got unexpected keyword argument "box_inches" which is no longer supported as of 3.3 and will become an error two minor releases later
# PyError ($(Expr(:escape, :(ccall(#= /home/ubuntu/.julia/packages/PyCall/BD546/src/pyfncall.jl:43 =# @pysym(:PyObject_Call), PyPtr, (PyPtr, PyPtr, PyPtr), o, pyargsptr, kw))))) <class 'FileNotFoundError'>
# FileNotFoundError(2, 'No such file or directory')
#   File "/home/ubuntu/.julia/conda/3/lib/python3.9/site-packages/matplotlib/figure.py", line 3005, in savefig
#     self.canvas.print_figure(fname, **kwargs)
#   File "/home/ubuntu/.julia/conda/3/lib/python3.9/site-packages/matplotlib/backend_bases.py", line 2255, in print_figure
#     result = print_method(
#   File "/home/ubuntu/.julia/conda/3/lib/python3.9/site-packages/matplotlib/backend_bases.py", line 1669, in wrapper
#     return func(*args, **kwargs)
#   File "/home/ubuntu/.julia/conda/3/lib/python3.9/site-packages/matplotlib/_api/deprecation.py", line 431, in wrapper
#     return func(*inner_args, **inner_kwargs)
#   File "/home/ubuntu/.julia/conda/3/lib/python3.9/site-packages/matplotlib/backends/backend_pdf.py", line 2718, in print_pdf
#     file = PdfFile(filename, metadata=metadata)
#   File "/home/ubuntu/.julia/conda/3/lib/python3.9/site-packages/matplotlib/backends/backend_pdf.py", line 637, in __init__
#     fh, opened = cbook.to_filehandle(filename, "wb", return_opened=True)
#   File "/home/ubuntu/.julia/conda/3/lib/python3.9/site-packages/matplotlib/cbook/__init__.py", line 462, in to_filehandle
#     fh = open(fname, flag, encoding=encoding)
#
#
# Stacktrace:
#   [1] pyerr_check
#     @ ~/.julia/packages/PyCall/BD546/src/exception.jl:62 [inlined]
#   [2] pyerr_check
#     @ ~/.julia/packages/PyCall/BD546/src/exception.jl:66 [inlined]
#   [3] _handle_error(msg::String)
#     @ PyCall ~/.julia/packages/PyCall/BD546/src/exception.jl:83
#   [4] macro expansion
#     @ ~/.julia/packages/PyCall/BD546/src/exception.jl:97 [inlined]
#   [5] #107
#     @ ~/.julia/packages/PyCall/BD546/src/pyfncall.jl:43 [inlined]
#   [6] disable_sigint
#     @ ./c.jl:458 [inlined]
#   [7] __pycall!
#     @ ~/.julia/packages/PyCall/BD546/src/pyfncall.jl:42 [inlined]
#   [8] _pycall!(ret::PyCall.PyObject, o::PyCall.PyObject, args::Tuple{String}, nargs::Int64, kw::PyCall.PyObject)
#     @ PyCall ~/.julia/packages/PyCall/BD546/src/pyfncall.jl:29
#   [9] _pycall!
#     @ ~/.julia/packages/PyCall/BD546/src/pyfncall.jl:11 [inlined]
#  [10] (::PyCall.PyObject)(args::String; kwargs::Base.Iterators.Pairs{Symbol, String, Tuple{Symbol}, NamedTuple{(:box_inches,), Tuple{String}}})
#     @ PyCall ~/.julia/packages/PyCall/BD546/src/pyfncall.jl:86
#  [11] top-level scope
#     @ In[20]:1
#  [12] eval
#     @ ./boot.jl:360 [inlined]
#  [13] include_string(mapexpr::typeof(REPL.softscope), mod::Module, code::String, filename::String)
#     @ Base ./loading.jl:1116

# %%
plt.rc("font", size="20")
function plotwave(ax, t, func;linewidth=1, linecolor="black")
    ydata = func.(t)
    ax.plot(t, ydata, linewidth=linewidth, color=linecolor)
    ax.set_xticks([minimum(t), maximum(t)])
    ax.set_yticks([minimum(ydata), maximum(ydata)])
    return ax
end

fig1,ax1=plt.subplots(figsize=(5,5))
fig2,ax2=plt.subplots(figsize=(5,5))
plotwave.([ax1,ax2], [0:0.1:500], [p1,p2])


ax1.set_xlim([0,250])
ax1.xaxis.set_ticks([0, 250])
ax2.set_xlim([0,250])
ax2.xaxis.set_ticks([0, 250])

#[a.set_xlabel("Time (seconds)") for a in [ax1,ax2]]
#[a.set_ylabel("Mitochondrial Damage (AU)") for a in [ax1,ax2]]
# Out:
# UndefVarError: p1 not defined
#
# Stacktrace:
#  [1] top-level scope
#    @ In[21]:12
#  [2] eval
#    @ ./boot.jl:360 [inlined]
#  [3] include_string(mapexpr::typeof(REPL.softscope), mod::Module, code::String, filename::String)
#    @ Base ./loading.jl:1116

# %%
fig1.savefig("FrequencyResponse/result/synthetic_wave/sine_low_freq.pdf")
fig2.savefig("FrequencyResponse/result/synthetic_wave/sine_high_freq.pdf")
# Out:
# PyError ($(Expr(:escape, :(ccall(#= /home/ubuntu/.julia/packages/PyCall/BD546/src/pyfncall.jl:43 =# @pysym(:PyObject_Call), PyPtr, (PyPtr, PyPtr, PyPtr), o, pyargsptr, kw))))) <class 'FileNotFoundError'>
# FileNotFoundError(2, 'No such file or directory')
#   File "/home/ubuntu/.julia/conda/3/lib/python3.9/site-packages/matplotlib/figure.py", line 3005, in savefig
#     self.canvas.print_figure(fname, **kwargs)
#   File "/home/ubuntu/.julia/conda/3/lib/python3.9/site-packages/matplotlib/backend_bases.py", line 2255, in print_figure
#     result = print_method(
#   File "/home/ubuntu/.julia/conda/3/lib/python3.9/site-packages/matplotlib/backend_bases.py", line 1669, in wrapper
#     return func(*args, **kwargs)
#   File "/home/ubuntu/.julia/conda/3/lib/python3.9/site-packages/matplotlib/_api/deprecation.py", line 431, in wrapper
#     return func(*inner_args, **inner_kwargs)
#   File "/home/ubuntu/.julia/conda/3/lib/python3.9/site-packages/matplotlib/backends/backend_pdf.py", line 2718, in print_pdf
#     file = PdfFile(filename, metadata=metadata)
#   File "/home/ubuntu/.julia/conda/3/lib/python3.9/site-packages/matplotlib/backends/backend_pdf.py", line 637, in __init__
#     fh, opened = cbook.to_filehandle(filename, "wb", return_opened=True)
#   File "/home/ubuntu/.julia/conda/3/lib/python3.9/site-packages/matplotlib/cbook/__init__.py", line 462, in to_filehandle
#     fh = open(fname, flag, encoding=encoding)
#
#
# Stacktrace:
#   [1] pyerr_check
#     @ ~/.julia/packages/PyCall/BD546/src/exception.jl:62 [inlined]
#   [2] pyerr_check
#     @ ~/.julia/packages/PyCall/BD546/src/exception.jl:66 [inlined]
#   [3] _handle_error(msg::String)
#     @ PyCall ~/.julia/packages/PyCall/BD546/src/exception.jl:83
#   [4] macro expansion
#     @ ~/.julia/packages/PyCall/BD546/src/exception.jl:97 [inlined]
#   [5] #107
#     @ ~/.julia/packages/PyCall/BD546/src/pyfncall.jl:43 [inlined]
#   [6] disable_sigint
#     @ ./c.jl:458 [inlined]
#   [7] __pycall!
#     @ ~/.julia/packages/PyCall/BD546/src/pyfncall.jl:42 [inlined]
#   [8] _pycall!(ret::PyCall.PyObject, o::PyCall.PyObject, args::Tuple{String}, nargs::Int64, kw::Ptr{Nothing})
#     @ PyCall ~/.julia/packages/PyCall/BD546/src/pyfncall.jl:29
#   [9] _pycall!
#     @ ~/.julia/packages/PyCall/BD546/src/pyfncall.jl:11 [inlined]
#  [10] #_#114
#     @ ~/.julia/packages/PyCall/BD546/src/pyfncall.jl:86 [inlined]
#  [11] (::PyCall.PyObject)(args::String)
#     @ PyCall ~/.julia/packages/PyCall/BD546/src/pyfncall.jl:86
#  [12] top-level scope
#     @ In[22]:1
#  [13] eval
#     @ ./boot.jl:360 [inlined]
#  [14] include_string(mapexpr::typeof(REPL.softscope), mod::Module, code::String, filename::String)
#     @ Base ./loading.jl:1116

# %%
p12 = p1 + p2
fig_2, ax_2 = plt.subplots(figsize=(5,5))
ax_2.plot(sol.t, [ p12(t) for t in sol.t], linewidth=1, color="black" )
ax_2.set_xlim([0,500])
ax_2.xaxis.set_ticks([0,500])
ax_2.yaxis.set_ticks([0,1])
# Out:
# UndefVarError: p1 not defined
#
# Stacktrace:
#  [1] top-level scope
#    @ In[23]:1
#  [2] eval
#    @ ./boot.jl:360 [inlined]
#  [3] include_string(mapexpr::typeof(REPL.softscope), mod::Module, code::String, filename::String)
#    @ Base ./loading.jl:1116

# %%
fig_2.savefig("FrequencyResponse/result/synthetic_wave/input.pdf", box_inches="tight")
# Out:
# UndefVarError: fig_2 not defined
#
# Stacktrace:
#  [1] top-level scope
#    @ In[24]:1
#  [2] eval
#    @ ./boot.jl:360 [inlined]
#  [3] include_string(mapexpr::typeof(REPL.softscope), mod::Module, code::String, filename::String)
#    @ Base ./loading.jl:1116

# %%
fig_, ax_ = plt.subplots(figsize=(5,5))
pr = pr_is
ax_.plot(sol.t, [sum(u[pr[:Rtg13_n]]) for u in sol.u], linewidth=3, color="blue")
ax_.xaxis.set_ticks([0,500])
ax_.set_xlim([0,500])
ax_.set_ylim([70,110])
ax_.yaxis.set_ticks([70,110])

fig_.savefig("FrequencyResponse/result/synthetic_wave/output_Rtg13_n.pdf", box_inches="tight")
# Out:
# sys:1: MatplotlibDeprecationWarning: savefig() got unexpected keyword argument "box_inches" which is no longer supported as of 3.3 and will become an error two minor releases later
# PyError ($(Expr(:escape, :(ccall(#= /home/ubuntu/.julia/packages/PyCall/BD546/src/pyfncall.jl:43 =# @pysym(:PyObject_Call), PyPtr, (PyPtr, PyPtr, PyPtr), o, pyargsptr, kw))))) <class 'FileNotFoundError'>
# FileNotFoundError(2, 'No such file or directory')
#   File "/home/ubuntu/.julia/conda/3/lib/python3.9/site-packages/matplotlib/figure.py", line 3005, in savefig
#     self.canvas.print_figure(fname, **kwargs)
#   File "/home/ubuntu/.julia/conda/3/lib/python3.9/site-packages/matplotlib/backend_bases.py", line 2255, in print_figure
#     result = print_method(
#   File "/home/ubuntu/.julia/conda/3/lib/python3.9/site-packages/matplotlib/backend_bases.py", line 1669, in wrapper
#     return func(*args, **kwargs)
#   File "/home/ubuntu/.julia/conda/3/lib/python3.9/site-packages/matplotlib/_api/deprecation.py", line 431, in wrapper
#     return func(*inner_args, **inner_kwargs)
#   File "/home/ubuntu/.julia/conda/3/lib/python3.9/site-packages/matplotlib/backends/backend_pdf.py", line 2718, in print_pdf
#     file = PdfFile(filename, metadata=metadata)
#   File "/home/ubuntu/.julia/conda/3/lib/python3.9/site-packages/matplotlib/backends/backend_pdf.py", line 637, in __init__
#     fh, opened = cbook.to_filehandle(filename, "wb", return_opened=True)
#   File "/home/ubuntu/.julia/conda/3/lib/python3.9/site-packages/matplotlib/cbook/__init__.py", line 462, in to_filehandle
#     fh = open(fname, flag, encoding=encoding)
#
#
# Stacktrace:
#   [1] pyerr_check
#     @ ~/.julia/packages/PyCall/BD546/src/exception.jl:62 [inlined]
#   [2] pyerr_check
#     @ ~/.julia/packages/PyCall/BD546/src/exception.jl:66 [inlined]
#   [3] _handle_error(msg::String)
#     @ PyCall ~/.julia/packages/PyCall/BD546/src/exception.jl:83
#   [4] macro expansion
#     @ ~/.julia/packages/PyCall/BD546/src/exception.jl:97 [inlined]
#   [5] #107
#     @ ~/.julia/packages/PyCall/BD546/src/pyfncall.jl:43 [inlined]
#   [6] disable_sigint
#     @ ./c.jl:458 [inlined]
#   [7] __pycall!
#     @ ~/.julia/packages/PyCall/BD546/src/pyfncall.jl:42 [inlined]
#   [8] _pycall!(ret::PyCall.PyObject, o::PyCall.PyObject, args::Tuple{String}, nargs::Int64, kw::PyCall.PyObject)
#     @ PyCall ~/.julia/packages/PyCall/BD546/src/pyfncall.jl:29
#   [9] _pycall!
#     @ ~/.julia/packages/PyCall/BD546/src/pyfncall.jl:11 [inlined]
#  [10] (::PyCall.PyObject)(args::String; kwargs::Base.Iterators.Pairs{Symbol, String, Tuple{Symbol}, NamedTuple{(:box_inches,), Tuple{String}}})
#     @ PyCall ~/.julia/packages/PyCall/BD546/src/pyfncall.jl:86
#  [11] top-level scope
#     @ In[25]:9
#  [12] eval
#     @ ./boot.jl:360 [inlined]
#  [13] include_string(mapexpr::typeof(REPL.softscope), mod::Module, code::String, filename::String)
#     @ Base ./loading.jl:1116

# %%
p12 = p1 + p2
fig_2, ax_2 = plt.subplots(figsize=(5,5))
ax_2.plot(sol.t, [ p12(t) for t in sol.t], linewidth=1, color="black" )
ax_2.set_xlim([0,500])
ax_2.xaxis.set_ticks([0,500])
ax_2.yaxis.set_ticks([0,1])

fig_2.savefig("FrequencyResponse/result/synthetic_wave/input.pdf", box_inches="tight")
# Out:
# UndefVarError: p1 not defined
#
# Stacktrace:
#  [1] top-level scope
#    @ In[26]:1
#  [2] eval
#    @ ./boot.jl:360 [inlined]
#  [3] include_string(mapexpr::typeof(REPL.softscope), mod::Module, code::String, filename::String)
#    @ Base ./loading.jl:1116

# %% [markdown]
# ## Plotting for Graphical Abstact

# %%
plotSol(solPulses, :Rtg3_n, dynmodel_sq;)
# Out:
# PyPlot.Figure(PyObject <Figure size 300x300 with 2 Axes>)
# (PyPlot.Figure(PyObject <Figure size 300x300 with 2 Axes>), nothing)

# %% [markdown]
# ### Increasing frequency of sine wave

# %%
function SINEV(t; t_start=0., t_end=600., ω_str=0.02, ω_end=0.7, amp=1.0, ϕ=π /2*3)
    ω_c = ω_str + (ω_end - ω_str)* (t-t_start)/(t_end-t_start)
    
    SIGNAL = 0.5*amp + 0.5*amp*sin(ω_c*t + ϕ)
    return SIGNAL
end


dynmodel_freq = DynModel(dynmodel; 
                       init_ss=false, 
                       tspan=(0.,600.),
                       signal_func= SINEV
                        );

sol = solve(dynmodel_freq;tmax=0.1);

# %%
## Plotting
out = get_sum(sol,:Rtg3_n, dynmodel_freq)
input = get_sum(sol,:s, dynmodel_freq)




fig,ax = plt.subplots(2,1; gridspec_kw= Dict(:height_ratios=> [1, 3]))

ax[1].plot(0:0.1:600, SINEV.(0:0.1:600); color="darkred", linewidth=1.5) # Input
ax[2].plot(sol.t, out;color="black", linewidth=1.5) #Output 


# Axis
ax[1].axis("off")

ax[2].yaxis.set_ticks([])
ax[2].xaxis.set_ticks([30, 450])

ax[2].set_xticklabels(["",""])
ax[2].set_xlim(30,450)
ax[1].set_xlim(30,450)
ax[2].set_ylim(250,350)


#ax[2].set_ylabel("Output", fontsize="20")
#ax[2].set_xlabel("Time", fontsize="20")




fig.subplots_adjust(
    hspace=0.
)

f = Fig(fig, ax, "Freq_low_high")
# Out:
# PyPlot.Figure(PyObject <Figure size 640x480 with 2 Axes>)
# Fig(PyPlot.Figure(PyObject <Figure size 640x480 with 2 Axes>), PyCall.PyObject[PyObject <AxesSubplot:>, PyObject <AxesSubplot:>], "Freq_low_high")

# %%
[save(f,"FreqVariant", "FrequencyResponse/result/GraphicalAbstract";format=i) for i in ["pdf", "svg"]]
# Out:
# IOError: mkdir("FrequencyResponse/result/GraphicalAbstract"; mode=0o777): no such file or directory (ENOENT)
#
# Stacktrace:
#   [1] uv_error
#     @ ./libuv.jl:97 [inlined]
#   [2] mkdir(path::String; mode::UInt16)
#     @ Base.Filesystem ./file.jl:179
#   [3] mkdir
#     @ ./file.jl:172 [inlined]
#   [4] save(f::Fig, secName::String, path_dir::String; format::String, transparent::Bool, bbox_inches::String, kwags::Base.Iterators.Pairs{Union{}, Union{}, Tuple{}, NamedTuple{(), Tuple{}}})
#     @ FrequencyResponse ~/MitoChannelAnalysis/FrequencyResponse/src/plot.jl:19
#   [5] (::var"#21#22")(i::String)
#     @ Main ./none:0
#   [6] iterate
#     @ ./generator.jl:47 [inlined]
#   [7] collect(itr::Base.Generator{Vector{String}, var"#21#22"})
#     @ Base ./array.jl:678
#   [8] top-level scope
#     @ In[30]:1
#   [9] eval
#     @ ./boot.jl:360 [inlined]
#  [10] include_string(mapexpr::typeof(REPL.softscope), mod::Module, code::String, filename::String)
#     @ Base ./loading.jl:1116

# %% [markdown]
# ## Bode Plot
# #'
# ### Amplitude Estimation

# %%
function gain(ω, dynmodel)
    sig = PosSine(ω=ω)
    tspan = (-100.,500. * 0.1 / ω)
    dynmodel_ = DynModel(dynmodel; 
                           tspan=tspan,
                           init_ss=false, 
                           signal_func= sig
                            );

    sol = solve(dynmodel_;tmax=1.);
    
    out = get_sum(sol,:Rtg3_n, dynmodel_)
    input_sig = sig.(sol.t)
    
    t0_tick = findfirst(x->x>=0, sol.t)
    maxO= maximum(out[t0_tick:end])
    minO = minimum(out[t0_tick:end])
    
    maxI = maximum(input_sig[t0_tick:end])
    minI = minimum(input_sig[t0_tick:end])
    
    return maxO, minO, maxI, minI,  input_sig, out,sol
    
end
# Out:
# gain (generic function with 1 method)

# %%
range(0,3;step=3)
# Out:
# 0:3:3

# %%
#[0.01, 0.1, 1, 10]
for ω in ProgressBar([0.01, 0.1, 1, 10, 100])
   
    # Gain
    maxO, minO, maxI, minI,  input_sig, out, sol = gain(ω, dynmodel)
    
    # Delay
    t_ran = (2*π/ω)*6
    tspan_ = sol.t[end] - t_ran: t_ran/100. : sol.t[end]
    

    t_shift = range(0,t_ran; length=length(tspan_) )
    
    tspan_crr = vcat(-t_shift[end:-1:2], t_shift)
   
    cross_cor = xcorr( [sol(i, idxs=1) for i in tspan_] , [ sum(sol.(i, idxs=rtg3_n)) for i in tspan_]   )
    

    
    max_t_tick = argmax(cross_cor)
    max_t = tspan_crr[max_t_tick]
    

    fig, ax = plt.subplots(1,3, figsize=(15,4))
    ax[1].plot(sol.t, input_sig)
    ax[1].axhline(maxI)
    ax[1].axhline(minI)
    ax[1].set_title("Input: ω=$(ω) rad/s")

    ax[2].plot(sol.t, out)
    ax[2].axhline(maxO)
    ax[2].axhline(minO)
    ax[2].set_title("Output (Rtg3_n)")
    
    ax[3].plot( tspan_crr ,cross_cor)
    ax[3].axvline(max_t)
    ax[3].set_title("Cross Correlation")
end
# Out:
# 0.0%┣                                            ┫ 0/5 [00:00<00:00, -20.0 it/s]
# 20.0%┣████████▋                                  ┫ 1/5 [00:13<Inf:Inf, 0.0 it/s]
# 40.0%┣██████████████████                           ┫ 2/5 [00:20<01:01, 0.0 it/s]
# 60.0%┣███████████████████████████                  ┫ 3/5 [00:27<00:27, 0.1 it/s]
# 80.0%┣████████████████████████████████████         ┫ 4/5 [00:34<00:11, 0.1 it/s]
# PyPlot.Figure(PyObject <Figure size 1500x400 with 3 Axes>)
# PyPlot.Figure(PyObject <Figure size 1500x400 with 3 Axes>)
# PyPlot.Figure(PyObject <Figure size 1500x400 with 3 Axes>)
# PyPlot.Figure(PyObject <Figure size 1500x400 with 3 Axes>)
# PyPlot.Figure(PyObject <Figure size 1500x400 with 3 Axes>)
# 100.0%┣████████████████████████████████████████████┫ 5/5 [00:41<00:00, 0.1 it/s]
# 100.0%┣████████████████████████████████████████████┫ 5/5 [00:41<00:00, 0.1 it/s]

# %%
ωs = 10 .^(-2.:0.1:1.)

amps = zeros(length(ωs))


for i in ProgressBar(1:length(ωs))
    maxO, minO, maxI, minI,  input_sig, out, sol = gain(ωs[i], dynmodel)
    amps[i] = maxO-minO
end
# Out:
# 0.0%┣                                           ┫ 0/31 [00:00<00:-2, -20.0 it/s]
# 3.2%┣█▍                                         ┫ 1/31 [00:08<Inf:Inf, 0.0 it/s]
# 6.5%┣███                                          ┫ 2/31 [00:15<07:10, 0.1 it/s]
# 9.7%┣████▍                                        ┫ 3/31 [00:22<05:08, 0.1 it/s]
# 12.9%┣█████▊                                      ┫ 4/31 [00:29<04:25, 0.1 it/s]
# 16.1%┣███████                                     ┫ 5/31 [00:37<03:59, 0.1 it/s]
# 19.4%┣████████▌                                   ┫ 6/31 [00:44<03:39, 0.1 it/s]
# 22.6%┣██████████                                  ┫ 7/31 [00:51<03:23, 0.1 it/s]
# 25.8%┣███████████▍                                ┫ 8/31 [00:57<03:09, 0.1 it/s]
# 29.0%┣████████████▊                               ┫ 9/31 [01:04<02:57, 0.1 it/s]
# 32.3%┣█████████████▉                             ┫ 10/31 [01:12<02:48, 0.1 it/s]
# 35.5%┣███████████████▎                           ┫ 11/31 [01:19<02:38, 0.1 it/s]
# 38.7%┣████████████████▋                          ┫ 12/31 [01:26<02:29, 0.1 it/s]
# 41.9%┣██████████████████                         ┫ 13/31 [01:33<02:20, 0.1 it/s]
# 45.2%┣███████████████████▍                       ┫ 14/31 [01:40<02:11, 0.1 it/s]
# 48.4%┣████████████████████▉                      ┫ 15/31 [01:47<02:03, 0.1 it/s]
# 51.6%┣██████████████████████▏                    ┫ 16/31 [01:55<01:55, 0.1 it/s]
# 54.8%┣███████████████████████▋                   ┫ 17/31 [02:02<01:46, 0.1 it/s]
# 58.1%┣█████████████████████████                  ┫ 18/31 [02:09<01:39, 0.1 it/s]
# 61.3%┣██████████████████████████▍                ┫ 19/31 [02:16<01:31, 0.1 it/s]
# 64.5%┣███████████████████████████▊               ┫ 20/31 [02:23<01:23, 0.1 it/s]
# 67.7%┣█████████████████████████████▏             ┫ 21/31 [02:30<01:15, 0.1 it/s]
# 71.0%┣██████████████████████████████▌            ┫ 22/31 [02:37<01:07, 0.1 it/s]
# 74.2%┣████████████████████████████████           ┫ 23/31 [02:44<01:00, 0.1 it/s]
# 77.4%┣█████████████████████████████████▎         ┫ 24/31 [02:51<00:52, 0.1 it/s]
# 80.6%┣██████████████████████████████████▊        ┫ 25/31 [02:58<00:45, 0.1 it/s]
# 83.9%┣████████████████████████████████████       ┫ 26/31 [03:05<00:37, 0.1 it/s]
# 87.1%┣█████████████████████████████████████▌     ┫ 27/31 [03:13<00:30, 0.1 it/s]
# 90.3%┣██████████████████████████████████████▉    ┫ 28/31 [03:20<00:22, 0.1 it/s]
# 93.5%┣████████████████████████████████████████▎  ┫ 29/31 [03:27<00:15, 0.1 it/s]
# 96.8%┣█████████████████████████████████████████▋ ┫ 30/31 [03:33<00:07, 0.1 it/s]
# 100.0%┣██████████████████████████████████████████┫ 31/31 [03:41<00:00, 0.1 it/s]
# 100.0%┣██████████████████████████████████████████┫ 31/31 [03:41<00:00, 0.1 it/s]

# %%
figg, axg = plt.subplots()
axg.plot(ωs, amps)
axg.set_yscale("log")
axg.set_xscale("log")
# Out:
# PyPlot.Figure(PyObject <Figure size 640x480 with 1 Axes>)

# %%
figg.savefig("FrequencyResponse/result/Bode/GainPlot.pdf";box_inches="tight", tranparent="true")
# Out:
# sys:1: MatplotlibDeprecationWarning: savefig() got unexpected keyword argument "box_inches" which is no longer supported as of 3.3 and will become an error two minor releases later
# sys:1: MatplotlibDeprecationWarning: savefig() got unexpected keyword argument "tranparent" which is no longer supported as of 3.3 and will become an error two minor releases later
# PyError ($(Expr(:escape, :(ccall(#= /home/ubuntu/.julia/packages/PyCall/BD546/src/pyfncall.jl:43 =# @pysym(:PyObject_Call), PyPtr, (PyPtr, PyPtr, PyPtr), o, pyargsptr, kw))))) <class 'FileNotFoundError'>
# FileNotFoundError(2, 'No such file or directory')
#   File "/home/ubuntu/.julia/conda/3/lib/python3.9/site-packages/matplotlib/figure.py", line 3005, in savefig
#     self.canvas.print_figure(fname, **kwargs)
#   File "/home/ubuntu/.julia/conda/3/lib/python3.9/site-packages/matplotlib/backend_bases.py", line 2255, in print_figure
#     result = print_method(
#   File "/home/ubuntu/.julia/conda/3/lib/python3.9/site-packages/matplotlib/backend_bases.py", line 1669, in wrapper
#     return func(*args, **kwargs)
#   File "/home/ubuntu/.julia/conda/3/lib/python3.9/site-packages/matplotlib/_api/deprecation.py", line 431, in wrapper
#     return func(*inner_args, **inner_kwargs)
#   File "/home/ubuntu/.julia/conda/3/lib/python3.9/site-packages/matplotlib/backends/backend_pdf.py", line 2718, in print_pdf
#     file = PdfFile(filename, metadata=metadata)
#   File "/home/ubuntu/.julia/conda/3/lib/python3.9/site-packages/matplotlib/backends/backend_pdf.py", line 637, in __init__
#     fh, opened = cbook.to_filehandle(filename, "wb", return_opened=True)
#   File "/home/ubuntu/.julia/conda/3/lib/python3.9/site-packages/matplotlib/cbook/__init__.py", line 462, in to_filehandle
#     fh = open(fname, flag, encoding=encoding)
#
#
# Stacktrace:
#   [1] pyerr_check
#     @ ~/.julia/packages/PyCall/BD546/src/exception.jl:62 [inlined]
#   [2] pyerr_check
#     @ ~/.julia/packages/PyCall/BD546/src/exception.jl:66 [inlined]
#   [3] _handle_error(msg::String)
#     @ PyCall ~/.julia/packages/PyCall/BD546/src/exception.jl:83
#   [4] macro expansion
#     @ ~/.julia/packages/PyCall/BD546/src/exception.jl:97 [inlined]
#   [5] #107
#     @ ~/.julia/packages/PyCall/BD546/src/pyfncall.jl:43 [inlined]
#   [6] disable_sigint
#     @ ./c.jl:458 [inlined]
#   [7] __pycall!
#     @ ~/.julia/packages/PyCall/BD546/src/pyfncall.jl:42 [inlined]
#   [8] _pycall!(ret::PyCall.PyObject, o::PyCall.PyObject, args::Tuple{String}, nargs::Int64, kw::PyCall.PyObject)
#     @ PyCall ~/.julia/packages/PyCall/BD546/src/pyfncall.jl:29
#   [9] _pycall!
#     @ ~/.julia/packages/PyCall/BD546/src/pyfncall.jl:11 [inlined]
#  [10] (::PyCall.PyObject)(args::String; kwargs::Base.Iterators.Pairs{Symbol, String, Tuple{Symbol, Symbol}, NamedTuple{(:box_inches, :tranparent), Tuple{String, String}}})
#     @ PyCall ~/.julia/packages/PyCall/BD546/src/pyfncall.jl:86
#  [11] top-level scope
#     @ In[36]:1
#  [12] eval
#     @ ./boot.jl:360 [inlined]
#  [13] include_string(mapexpr::typeof(REPL.softscope), mod::Module, code::String, filename::String)
#     @ Base ./loading.jl:1116

# %% [markdown]
# ## Phase

# %%
maxO, minO, maxI, minI,  input_sig, out, sol = gain(0.4, dynmodel);

# %%
maxO, minO, maxI, minI
# Out:
# (303.5436765908827, 303.4924859632272, 0.9994688305131253, 1.655317805437928e-6)

# %%
plt.plot(xcorr( [sol(i, idxs=1) for i in 0:0.01:10] , [ sum(sol.(i, idxs=rtg3_n)) for i in 0:0.1:100]   ) )
# Out:
# PyPlot.Figure(PyObject <Figure size 640x480 with 1 Axes>)
# 1-element Vector{PyCall.PyObject}:
#  PyObject <matplotlib.lines.Line2D object at 0x7fceee3b1250>
